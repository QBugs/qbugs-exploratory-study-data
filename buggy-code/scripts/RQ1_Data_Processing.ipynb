# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import math

# %%
buggy_elements = pd.read_csv('../data/RQ1_Data.csv')

# %%
buggy_elements.head()

# %%
pd.set_option('display.max_colwidth', None)

# %%
buggy_elements['Changes']= " "

# %%
buggy_elements['Component']= " "

# %%
i =0 


for values in buggy_elements['Values']:

    if('<class \'_ast.Return\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A return statement was changed/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Return'
    if('<class \'_ast.Call\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A function call was changed/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Function Call'
    if('<class \'_ast.Delete\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A statement was deleted/changed using the del keyword'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Del keyword'
    if('<class \'_ast.Assign\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#An assign statement was changed/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Assignment'
    if('<class \'_ast.AugAssign\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#An augmented assign statement was changed/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Augmented Assignment'
    if('<class \'_ast.AnnAssign\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#An annotated assign statement was changed/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Annotated assignment'
    if('<class \'_ast.For\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#There was a change/deletion in a for loop'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#For loop'
    if('<class \'_ast.AsyncFor\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#There was a change/deletion in an asynchronous for loop'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Async For Loop'
    if('<class \'_ast.While\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#There was a change/deletion in a while loop'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#While loop'
    if('<class \'_ast.If\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#There was a change/deletion in an if statement'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#If statement'
    if('<class \'_ast.With\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#There was a change/deletion using the with keyword, which is used when working with unmanaged resources'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#With keyword'
    if('<class \'_ast.AsyncWith\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#There was a change/deletion using the asynchronous with keyword, which is used when working with unmanaged resources'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Async With keyword'
    if('<class \'_ast.Match\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A pattern matching statement was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Match keyword'
    if('<class \'_ast.Raise\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#An exception raised was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + 'Raise exception'
    if('<class \'_ast.Try\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A try statement, used for exception catching, was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Try exception'
    if('<class \'_ast.Assert\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#An assertion to a given condition was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Assertion'
    if('<class \'_ast.Import\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#An import was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Import keyword'
    if('<class \'_ast.ImportFrom\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#An import from a module statement was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#ImportFrom keyword'
    if('<class \'_ast.Global\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A global variable was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Global variable'
    if('<class \'_ast.NonLocal\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A non local variable  was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Non Local Variable'
    if('<class \'_ast.Break\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A break statement, used to break a loop, was modified/deleted '
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Break '
    if('<class \'_ast.Continue\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A continue statement, used to stop the current iteration of a loop and go to the next iteration of a loop, was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Continue'
    if('<class \'_ast.Pass\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A pass statement was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Pass'
    if('<class \'_ast.BoolOp\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A boolean operator was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Boolean Operator'
    if('<class \'_ast.NamedExpr\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A named expression was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Named Expression'
    if('<class \'_ast.BinOp\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A binary operator was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Binary Operator'
    if('<class \'_ast.UnaryOp\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A unitary operator was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Unary Operator'
    if('<class \'_ast.Lambda\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A lambda function was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Lambda'
    if('<class \'_ast.IfExp\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A conditional expression modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Conditional expression'
    if('<class \'_ast.ListComp\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A list comprehension was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#List comprehension'
    if('<class \'_ast.SetComp\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A set comprehension was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Set comprehension'
    if('<class \'_ast.DictComp\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A dictionary comprehesion was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Dictionary comprehension'
    if('<class \'_ast.GeneratorExp\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#An object generator was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Object generator'
    if('<class \'_ast.Await\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#An await expression, using for asynchrounous functiond was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Await expression'
    if('<class \'_ast.Yield\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A yield expression was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Yield expression'
    if('<class \'_ast.YieldFrom\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A yieldFrom expression was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#YieldFrom expression'
    if('<class \'_ast.Compare\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A compare expression using comparison operators such as == was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Comparison expression'
    if('<class \'_ast.Constant\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A constant whose value cannot be changed was deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Constant'
    if('<class \'_ast.Tuple\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A tuple was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Tuple'
    if('<class \'_ast.List\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#A list was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#List'
    if('<class \'_ast.Attribute\'>' in values):
        buggy_elements.loc[i,['Changes']] = buggy_elements.loc[i,['Changes']] + '#An attribute was modified/deleted'
        buggy_elements.loc[i,['Component']] = buggy_elements.loc[i,['Component']] + '#Attribute'
        
        
        print( buggy_elements.loc[i,['Changes']])
    
    i = i + 1

# %%
buggy_elements.to_csv('..\data\RQ1_Data_Processed.csv', index = False, encoding='utf-8')
